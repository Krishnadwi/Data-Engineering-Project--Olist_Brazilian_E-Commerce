# %% [markdown]
# #Save as Parquet in HDFS

# %%
full_order_df.write.mode("overwrite").parquet('/olist/proc')

# %% [markdown]
# #Save is as parquet in Google Cloud Storage

# %%
full_order_df.write.mode("overwrite").parquet('gs://your_bucket')

# %% [markdown]
# #Save in HIVE

# %%
full_order_df.write.mode("overwrite").saveAsTable("full_order_detail")
